# %% [markdown]
# # S2. Python intro
#
# На входе у нас данные показаний экодатчиков. Показания идут последовательными пакетами, в каждом пакете 3 элемента - время получения пакета (timestamp), значение PM2.5, значение температуры
# Эти показания вы получаете в виде списка, каждом элементом списка является кортеж (tuple)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
rawdata = [
(1663567274, 15.16, 18.07),
(1663567276, 14.25, 18.09),
(1663567278, 13.31, 18.10),
(1663567280, 13.46, 17.98),
(1663567282, 15.02, 18.00),
(1663567284, 14.85, 18.03),
(1663567286, 14.75, 17.98),
(1663567288, 13.85, 18.09),
(1663567290, 13.33, 18.06),
(1663567292, 13.60, 18.10),
(1663567294, 26.86, 18.57),
(1663567296, 48.42, 18.66),
(1663567298, 37.90, 18.72),
(1663567300, 30.29, 18.31),
(1663567302, 19.81, 18.40),
(1663567304, 13.35, 18.23),
(1663567306, 14.90, 18.08),
(1663567308, 15.24, 18.08),
(1663567310, 14.74, 18.20),
(1663567312, 13.72, 18.17),
(1663567314, 14.09, 18.27),
(1663567316, 15.05, 18.32),
(1663567318, 13.99, 18.31),
(1663567320, 13.54, 18.16),
(1663567322, 14.86, 18.20),
(1663567324, 13.92, 18.35),
(1663567326, 14.90, 18.36),
(1663567328, 15.23, 18.35),
(1663567330, 14.45, 18.26),
(1663567332, 15.08, 18.32),
(1663567334, 27.68, 18.42),
(1663567336, 30.25, 18.36),
(1663567338, 19.99, 18.24),
(1663567340, 15.22, 18.37),
(1663567342, 14.05, 18.32),
(1663567344, 15.26, 18.40),
(1663567346, 14.82, 18.40),
(1663567348, 13.46, 18.37),
(1663567350, 14.68, 18.38),
(1663567352, 14.42, 18.47),
(1663567354, 15.11, 18.51),
(1663567356, 13.83, 18.36),
(1663567358, 15.10, 18.43),
(1663567360, 36.37, 18.66),
(1663567362, 51.23, 18.98),
(1663567364, 31.01, 18.83),
(1663567366, 24.62, 18.69),
(1663567368, 13.73, 18.36),
(1663567370, 14.42, 18.48),
(1663567372, 14.16, 18.45),    
]

# %%
rawdata = [
(1663567274, 15.16, 18.07),
(1663567276, 14.25, 18.09),
(1663567278, 13.31, 18.10),
(1663567280, 13.46, 17.98),
(1663567282, 15.02, 18.00),
(1663567284, 14.85, 18.03),
(1663567286, 14.75, 17.98),
(1663567288, 13.85, 18.09),
(1663567290, 13.33, 18.06),
(1663567292, 13.60, 18.10),
(1663567294, 26.86, 18.57),
(1663567296, 48.42, 18.66),
(1663567298, 37.90, 18.72),
(1663567300, 30.29, 18.31),
(1663567302, 19.81, 18.40),
(1663567304, 13.35, 18.23),
(1663567306, 14.90, 18.08),
(1663567308, 15.24, 18.08),
(1663567310, 14.74, 18.20),
(1663567312, 13.72, 18.17),
(1663567314, 14.09, 18.27),
(1663567316, 15.05, 18.32),
(1663567318, 13.99, 18.31),
(1663567320, 13.54, 18.16),
(1663567322, 14.86, 18.20),
(1663567324, 13.92, 18.35),
(1663567326, 14.90, 18.36),
(1663567328, 15.23, 18.35),
(1663567330, 14.45, 18.26),
(1663567332, 15.08, 18.32),
(1663567334, 27.68, 18.42),
(1663567336, 30.25, 18.36),
(1663567338, 19.99, 18.24),
(1663567340, 15.22, 18.37),
(1663567342, 14.05, 18.32),
(1663567344, 15.26, 18.40),
(1663567346, 14.82, 18.40),
(1663567348, 13.46, 18.37),
(1663567350, 14.68, 18.38),
(1663567352, 14.42, 18.47),
(1663567354, 15.11, 18.51),
(1663567356, 13.83, 18.36),
(1663567358, 15.10, 18.43),
(1663567360, 36.37, 18.66),
(1663567362, 51.23, 18.98),
(1663567364, 31.01, 18.83),
(1663567366, 24.62, 18.69),
(1663567368, 13.73, 18.36),
(1663567370, 14.42, 18.48),
(1663567372, 14.16, 18.45),    
]

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import plot

string = "Beautiful is better than ugly.Explicit is better than implicit.Simple is better than complex.Complex is better than complicated.Flat is better than nested.Sparse is better than dense.Readability counts.Special cases aren't special enough to break the rules.Although practicality beats purity.Errors should never pass silently.Unless explicitly silenced.In the face of ambiguity, refuse the temptation to guess.There should be one-- and preferably only one --obvious way to do it.Although that way may not be obvious at first unless you're Dutch.Now is better than never.Although never is often better than *right* now.If the implementation is hard to explain, it's a bad idea.If the implementation is easy to explain, it may be a good idea.Namespaces are one honking great idea -- let's do more of those!"



s_string = set(string)
summ = []
for s_symbol in s_string:
    count = 0
    for symbol in string:
        if s_symbol == symbol or s_symbol == symbol.islower():
            count += 1
    summ.append((s_symbol, count))

list_of_symbols = [item[0] for item in summ]
list_of_symbols_summ = [item[1] for item in summ]

plot(list_of_symbols, list_of_symbols_summ, linewidth=2.0, color="b")

# %%
# для отображения графиков нужны массивы координат

# массива координат X будет достаточно одного
x = range(len(rawdata))

# по y мы будем отображать значения PM2.5 и температуры
pm = [item[1] for item in rawdata]
temp = [item[2] for item in rawdata]

# %%
# Коды цветов:
# 'b' as blue
# 'g' as green
# 'r' as red
# 'c' as cyan
# 'm' as magenta
# 'y' as yellow
# 'k' as black
# 'w' as white

plt.plot(x, pm, linewidth=2.0, color="b", label="PM2.5")
plt.plot(x, temp, linewidth=2.0, color="r", label="Temperature")

plt.legend() #Подписать названия графиков
plt.show()

# %% [markdown]
# ## Задача:
#
# 1. Для массива pm найти среднее арифметическое и медиану, и отобразить их на графике
# 2. Для массива температур найти среднее арифметическое и медиану, и отобразить их на графике
#
# *Среднее арифметическое* - это сумма всех значений, поделенная на количество значений
#
# *Медиана* - это значение среднего по величине элемента

# %%
import matplotlib.pyplot as plt
import string

string1 = "Beautiful is better than ugly.Explicit is better than implicit.Simple is better than complex.Complex is better than complicated.Flat is better than nested.Sparse is better than dense.Readability counts.Special cases aren't special enough to break the rules.Although practicality beats purity.Errors should never pass silently.Unless explicitly silenced.In the face of ambiguity, refuse the temptation to guess.There should be one-- and preferably only one --obvious way to do it.Although that way may not be obvious at first unless you're Dutch.Now is better than never.Although never is often better than *right* now.If the implementation is hard to explain, it's a bad idea.If the implementation is easy to explain, it may be a good idea.Namespaces are one honking great idea -- let's do more of those!"

string_lower = string1.lower()

string_lower.replace(' ', '-')


string_lower = string_lower.translate(str.maketrans('', '', string.punctuation))

s_string = set(string_lower)
summ = []
for s_symbol in s_string:
    count = 0
    for symbol in string1:
        if s_symbol == symbol:
            count += 1
    summ.append((s_symbol, count))


list_of_symbols = [item[0] for item in summ]
list_of_symbols_summ = [item[1] for item in summ]

list_of_symbols_summ_sorted = sorted(list_of_symbols_summ)
list_of_symbols_sorted = sorted(list_of_symbols)

plot(list_of_symbols, list_of_symbols_summ, linewidth=2.0, color="b")

# %%
import matplotlib.pyplot as plt
import string

string1 = "Beautiful is better than ugly.Explicit is better than implicit.Simple is better than complex.Complex is better than complicated.Flat is better than nested.Sparse is better than dense.Readability counts.Special cases aren't special enough to break the rules.Although practicality beats purity.Errors should never pass silently.Unless explicitly silenced.In the face of ambiguity, refuse the temptation to guess.There should be one-- and preferably only one --obvious way to do it.Although that way may not be obvious at first unless you're Dutch.Now is better than never.Although never is often better than *right* now.If the implementation is hard to explain, it's a bad idea.If the implementation is easy to explain, it may be a good idea.Namespaces are one honking great idea -- let's do more of those!"

string_lower = string1.lower()

string_lower.replace(' ', '-')


string_lower = string_lower.translate(str.maketrans('', '', string.punctuation))

s_string = set(string_lower)
summ = []
for s_symbol in s_string:
    count = 0
    for symbol in string1:
        if s_symbol == symbol:
            count += 1
    summ.append((s_symbol, count))


list_of_symbols = [item[0] for item in summ]
list_of_symbols_summ = [item[1] for item in summ]

list_of_symbols_summ_sorted = sorted(list_of_symbols_summ)
list_of_symbols_sorted = sorted(list_of_symbols)

plot(list_of_symbols, list_of_symbols_summ, linewidth=2.0, color="b")
